# %% [markdown]
# <a href="https://colab.research.google.com/github/DolrajRijal/helloworld/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('/content/company_sales_data.csv')
df.head()
x = df['month_number'].tolist()
y = df['total_profit'].tolist()
plt.plot(x,y,label = "total monthly profit in a year")
plt.xticks(x)
plt.xlabel("month number")
plt.ylabel("total profit")
#rint(df)
# Out:
# Text(0, 0.5, 'total profit')

# %% [markdown]
# Line plot with various styling

# %%
#import matplotlib.pyplot as plt
#import pandas as pd
#df = pd.read_csv('/content/company_sales_data.csv')    
#print(df)
month_list = df['month_number'].tolist()
profit_list = df['total_profit'].tolist()
plt.plot(month_list,profit_list,color = 'r',marker = 'o' ,markerfacecolor = 'k',
linestyle = '--',linewidth = 2)

# %% [markdown]
# reading data and showing a multiline plot

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('/content/company_sales_data.csv')

facecream_list = df['facecream'].tolist()   
facewash_list = df['facewash'].tolist()
toothpaste_list =df['toothpaste']
bathingsoap_list =df['bathingsoap']
shampoo =df['shampoo']
moisturizer_list = df['moisturizer']
total_units_list = df['total_units']

 
plt.plot(month_list,facecream_list, label = 'fcsells',color = 'y', marker = 's', markerfacecolor = 'r', linestyle = ':', linewidth = 2)     


plt.plot(month_list,bathingsoap_list, label = 'bssells',color = 'g', marker = 'D', markerfacecolor = 'c', linestyle = '-.')



plt.plot(month_list,shampoo, label = 'shmpsells',color = 'b', marker = '+', markerfacecolor = 'r', linestyle = 'solid')

plt.plot(month_list,moisturizer_list, label = 'moistzrsells',color = 'm', marker = 'H', markerfacecolor = 'w', linestyle = 'dashed')


plt.plot(month_list,total_units_list, label = 'fcsells',color = 'c', marker = 'x', markerfacecolor = 'r', linestyle = ':',linewidth = 3)
